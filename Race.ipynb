# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\users\yuxch\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\yuxch\anaconda3\lib\site-packages (from geopy) (2.0)

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
from geopy.extra.rate_limiter import RateLimiter

# %%
df = pd.read_csv(r"C:\Users\yuxch\Downloads\Race .csv")
df.head()
# Out:
#    Place    First     Last              City State  Age Division     Time
# 0      1   Daniel   Wilson             Tulsa    OK   35        M  8:23:01
# 1      2     Eric    Davis         Greenwood    IN   38        M  8:57:54
# 2      3  Stewart  Edwards  New Smyrna Beach    FL   43        M  9:24:35
# 3      4      Ron  Hammett         Montverde    FL   53        M  9:24:36
# 4      5     Seth     Cain            Geneva    FL   44        M  9:42:17

# %%
df2 = df.dropna()
df2
# Out:
#      Place     First          Last              City State  Age Division  \
# 0        1    Daniel        Wilson             Tulsa    OK   35        M
# 1        2      Eric         Davis         Greenwood    IN   38        M
# 2        3   Stewart       Edwards  New Smyrna Beach    FL   43        M
# 3        4       Ron       Hammett         Montverde    FL   53        M
# 4        5      Seth          Cain            Geneva    FL   44        M
# ..     ...       ...           ...               ...   ...  ...      ...
# 104    105     David        Buning       Winter Park    FL   49        M
# 105    106     Kelly  Stoner Baker         Woodstock    GA   53        F
# 106    107      Chad          Ward         Woodstock    GA   39        M
# 107    108    Dennis     Stadelman            Cicero    NY   62        M
# 108    109  Jonathan       Burnham        Fort Moore    GA   24        M
#
#          Time
# 0     8:23:01
# 1     8:57:54
# 2     9:24:35
# 3     9:24:36
# 4     9:42:17
# ..        ...
# 104  15:03:26
# 105  15:09:19
# 106  15:10:30
# 107  15:20:26
# 108  15:40:49
#
# [109 rows x 8 columns]

# %%
df2['fullname'] = df2['First'] + ' ' + df2['Last']
df2
# Out:
#      Place     First          Last              City State  Age Division  \
# 0        1    Daniel        Wilson             Tulsa    OK   35        M
# 1        2      Eric         Davis         Greenwood    IN   38        M
# 2        3   Stewart       Edwards  New Smyrna Beach    FL   43        M
# 3        4       Ron       Hammett         Montverde    FL   53        M
# 4        5      Seth          Cain            Geneva    FL   44        M
# ..     ...       ...           ...               ...   ...  ...      ...
# 104    105     David        Buning       Winter Park    FL   49        M
# 105    106     Kelly  Stoner Baker         Woodstock    GA   53        F
# 106    107      Chad          Ward         Woodstock    GA   39        M
# 107    108    Dennis     Stadelman            Cicero    NY   62        M
# 108    109  Jonathan       Burnham        Fort Moore    GA   24        M
#
#          Time            fullname
# 0     8:23:01       Daniel Wilson
# 1     8:57:54          Eric Davis
# 2     9:24:35     Stewart Edwards
# 3     9:24:36         Ron Hammett
# 4     9:42:17           Seth Cain
# ..        ...                 ...
# 104  15:03:26        David Buning
# 105  15:09:19  Kelly Stoner Baker
# 106  15:10:30           Chad Ward
# 107  15:20:26    Dennis Stadelman
# 108  15:40:49    Jonathan Burnham
#
# [109 rows x 9 columns]

# %%
df2['Time'] = pd.to_timedelta(df2['Time'])
df2['Total_Minutes'] = df2['Time'].dt.total_seconds() / 60
df2['Total_Minutes'] = df2['Total_Minutes'].round().astype(int)
df2
# Out:
#      Place     First          Last              City State  Age Division  \
# 0        1    Daniel        Wilson             Tulsa    OK   35        M
# 1        2      Eric         Davis         Greenwood    IN   38        M
# 2        3   Stewart       Edwards  New Smyrna Beach    FL   43        M
# 3        4       Ron       Hammett         Montverde    FL   53        M
# 4        5      Seth          Cain            Geneva    FL   44        M
# ..     ...       ...           ...               ...   ...  ...      ...
# 104    105     David        Buning       Winter Park    FL   49        M
# 105    106     Kelly  Stoner Baker         Woodstock    GA   53        F
# 106    107      Chad          Ward         Woodstock    GA   39        M
# 107    108    Dennis     Stadelman            Cicero    NY   62        M
# 108    109  Jonathan       Burnham        Fort Moore    GA   24        M
#
#                Time            fullname  Total_Minutes
# 0   0 days 08:23:01       Daniel Wilson            503
# 1   0 days 08:57:54          Eric Davis            538
# 2   0 days 09:24:35     Stewart Edwards            565
# 3   0 days 09:24:36         Ron Hammett            565
# 4   0 days 09:42:17           Seth Cain            582
# ..              ...                 ...            ...
# 104 0 days 15:03:26        David Buning            903
# 105 0 days 15:09:19  Kelly Stoner Baker            909
# 106 0 days 15:10:30           Chad Ward            910
# 107 0 days 15:20:26    Dennis Stadelman            920
# 108 0 days 15:40:49    Jonathan Burnham            941
#
# [109 rows x 10 columns]

# %%
df2.rename(columns = {'Division': 'Gender'}, inplace = True)

# %%
df2
# Out:
#      Place     First          Last              City State  Age Gender  \
# 0        1    Daniel        Wilson             Tulsa    OK   35      M
# 1        2      Eric         Davis         Greenwood    IN   38      M
# 2        3   Stewart       Edwards  New Smyrna Beach    FL   43      M
# 3        4       Ron       Hammett         Montverde    FL   53      M
# 4        5      Seth          Cain            Geneva    FL   44      M
# ..     ...       ...           ...               ...   ...  ...    ...
# 104    105     David        Buning       Winter Park    FL   49      M
# 105    106     Kelly  Stoner Baker         Woodstock    GA   53      F
# 106    107      Chad          Ward         Woodstock    GA   39      M
# 107    108    Dennis     Stadelman            Cicero    NY   62      M
# 108    109  Jonathan       Burnham        Fort Moore    GA   24      M
#
#                Time            fullname  Total_Minutes
# 0   0 days 08:23:01       Daniel Wilson            503
# 1   0 days 08:57:54          Eric Davis            538
# 2   0 days 09:24:35     Stewart Edwards            565
# 3   0 days 09:24:36         Ron Hammett            565
# 4   0 days 09:42:17           Seth Cain            582
# ..              ...                 ...            ...
# 104 0 days 15:03:26        David Buning            903
# 105 0 days 15:09:19  Kelly Stoner Baker            909
# 106 0 days 15:10:30           Chad Ward            910
# 107 0 days 15:20:26    Dennis Stadelman            920
# 108 0 days 15:40:49    Jonathan Burnham            941
#
# [109 rows x 10 columns]

# %%
df2.to_csv('cleaned_data.csv', index = False)
